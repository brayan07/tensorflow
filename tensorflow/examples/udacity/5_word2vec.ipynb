# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5244, 3082, 12, 6, 195, 2, 3135, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'a', 'anarchism', 'term', 'of', 'originated', 'as', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.631870
# Nearest to use: denies, cana, speeding, numa, written, nasir, alam, satirical,
# Nearest to between: national, headgear, loti, mies, patriarchates, wharton, versatile, circumcise,
# Nearest to over: apollinaire, fai, daytona, jt, democratisation, resumed, satchmo, firestone,
# Nearest to s: physik, bout, pas, bulletproof, alignment, shaolin, singular, normalcy,
# Nearest to can: dorpat, additive, pause, slapping, intonation, medusa, paganism, baloch,
# Nearest to to: altering, brasil, follicle, respecting, disruptions, homomorphism, organiser, slashes,
# Nearest to UNK: blaylock, retroviruses, shenouda, dependent, diane, accomplishes, inalienable, cfaf,
# Nearest to united: populations, elucidation, hipc, secondo, curator, relief, planned, dia,
# Nearest to new: referent, hex, reelection, duarte, kilmister, bethany, need, prescott,
# Nearest to has: trout, olof, heifer, renovate, igg, auks, reals, now,
# Nearest to would: bckgr, trainees, frosts, cante, xin, invents, archipelagoes, unary,
# Nearest to six: kodiak, dialing, poultry, cosmologies, discounts, maple, lymphatic, myung,
# Nearest to had: odegard, pumpkins, strunk, harbored, hatti, oldfield, mushrooms, antagonists,
# Nearest to up: wrestling, mandelbrot, sharks, epiphanes, megaliths, bellum, lagers, wah,
# Nearest to about: inflections, heretofore, cri, kish, bodybuilder, xxx, kilda, protista,
# Nearest to known: prevented, irritant, aids, editorship, sfg, falla, suggestive, hamas,
# Average loss at step 2000: 4.370632
# Average loss at step 4000: 3.864111
# Average loss at step 6000: 3.787460
# Average loss at step 8000: 3.692652
# Average loss at step 10000: 3.615567
# Nearest to use: pedestal, satirical, wie, nasir, pluralized, enfant, bryant, cana,
# Nearest to between: national, loti, patriarchates, with, vector, histoire, headgear, nbs,
# Nearest to over: dovich, here, democratisation, owes, firestone, kuru, jt, munroe,
# Nearest to s: alignment, his, mountaineer, and, commemorating, neuch, composers, urge,
# Nearest to can: may, would, will, could, polysaccharides, dorpat, superintendent, civilize,
# Nearest to to: breatharian, piracy, organiser, mirrored, mechon, not, vessels, global,
# Nearest to UNK: eniac, inflating, resource, esdras, h, stony, drumming, palomino,
# Nearest to united: orioles, hipc, relief, secondo, curator, convince, populations, andrew,
# Nearest to new: referent, hex, reside, arrogance, reelection, flags, need, kauravas,
# Nearest to has: had, was, have, is, igg, auditum, became, subjecting,
# Nearest to would: can, could, may, frosts, elamite, bckgr, chronos, cante,
# Nearest to six: eight, seven, nine, five, four, three, zero, two,
# Nearest to had: was, have, has, compositing, jorge, amino, solids, detective,
# Nearest to up: cremated, epiphanes, megaliths, weishaupt, uprooted, sharks, poking, revolver,
# Nearest to about: mebyon, midyear, heretofore, newark, cri, futility, cookies, bodybuilder,
# Nearest to known: a, aids, prevented, humayun, sfg, hamas, molds, administrator,
# Average loss at step 12000: 3.605441
# Average loss at step 14000: 3.573691
# Average loss at step 16000: 3.410952
# Average loss at step 18000: 3.460775
# Average loss at step 20000: 3.535995
# Nearest to use: pluralized, satirical, pedestal, wie, prefer, nasir, kleine, direction,
# Nearest to between: with, from, loti, patriarchates, national, nbs, mies, emulsions,
# Nearest to over: democratisation, kuru, informational, munroe, clearance, dovich, owes, woodcock,
# Nearest to s: alignment, mountaineer, imperatoribus, clones, kristian, hatti, zach, azteca,
# Nearest to can: may, will, could, would, must, should, cannot, medusa,
# Nearest to to: will, may, would, could, can, against, intermission, piracy,
# Nearest to UNK: consanguinity, palomino, la, bilayer, enrique, mortuary, lincoln, itu,
# Nearest to united: orioles, hipc, truffaut, relief, whitfield, convince, peloponnesian, svalbard,
# Nearest to new: referent, hex, reelection, reside, flags, flipping, cofinality, arrogance,
# Nearest to has: had, have, was, is, schleicher, fayette, remark, subjecting,
# Nearest to would: could, may, can, will, might, should, must, elamite,
# Nearest to six: four, seven, eight, nine, five, three, two, zero,
# Nearest to had: has, have, was, were, been, jorge, solids, eloquent,
# Nearest to up: cremated, him, them, weishaupt, conservationist, uprooted, megaliths, revolver,
# Nearest to about: mebyon, newark, inflections, countenance, dire, cern, heretofore, annales,
# Nearest to known: such, used, nana, humayun, dmd, administrator, hamas, imperatives,
# Average loss at step 22000: 3.499967
# Average loss at step 24000: 3.491570
# Average loss at step 26000: 3.484208
# Average loss at step 28000: 3.483259
# Average loss at step 30000: 3.503337
# Nearest to use: prefer, wie, juxtaposition, smoothing, enfant, pedestal, give, kleine,
# Nearest to between: with, in, from, loti, patriarchates, national, fearsome, fragment,
# Nearest to over: democratisation, kuru, informational, woodcock, during, clearance, euphoric, owes,
# Nearest to s: his, modernity, clones, petrochemicals, internationalism, rowboat, chloe, eucharistic,
# Nearest to can: may, could, would, will, must, should, cannot, might,
# Nearest to to: would, will, can, could, witches, towards, intermission, not,
# Nearest to UNK: martialed, e, resource, chanced, invades, phosphorus, h, lincoln,
# Nearest to united: hipc, orioles, peloponnesian, world, svalbard, truffaut, whitfield, curiae,
# Nearest to new: referent, gardnerian, original, kauravas, sees, barbie, modernists, marko,
# Nearest to has: had, have, is, was, schleicher, shrunk, unprecedented, abeokuta,
# Nearest to would: could, can, may, will, might, must, should, to,
# Nearest to six: eight, seven, four, nine, five, three, two, zero,
# Nearest to had: has, have, was, were, wrc, is, instantaneous, since,
# Nearest to up: them, him, cremated, delegation, conservationist, revolver, nijmegen, megaliths,
# Nearest to about: mebyon, newark, countenance, staple, heel, midyear, colophon, inflections,
# Nearest to known: used, defined, such, nana, well, called, sierpinski, administrator,
# Average loss at step 32000: 3.502787
# Average loss at step 34000: 3.493219
# Average loss at step 36000: 3.460049
# Average loss at step 38000: 3.304091
# Average loss at step 40000: 3.429501
# Nearest to use: prefer, wie, juxtaposition, explain, topped, give, enfant, tirelessly,
# Nearest to between: with, patriarchates, islanders, through, loti, usc, sibling, senses,
# Nearest to over: munroe, up, gpl, woodcock, exacting, democratisation, huguenot, euphoric,
# Nearest to s: his, internationalism, modernity, ballantine, za, eucharistic, diomedes, nixon,
# Nearest to can: may, could, would, will, must, should, cannot, might,
# Nearest to to: could, must, will, can, indignant, would, intermission, knife,
# Nearest to UNK: b, h, d, opera, techs, solicit, margrave, aruba,
# Nearest to united: hipc, orioles, whitfield, peloponnesian, curiae, truffaut, childbearing, convince,
# Nearest to new: kauravas, modernists, gladly, sees, laconic, duarte, manuel, partner,
# Nearest to has: had, have, was, is, storied, since, instantaneous, fayetteville,
# Nearest to would: could, can, will, may, might, must, should, did,
# Nearest to six: five, four, seven, eight, three, nine, two, zero,
# Nearest to had: has, have, was, were, bookmakers, wrc, been, having,
# Nearest to up: them, him, cremated, out, nijmegen, over, delegation, obligated,
# Nearest to about: xxx, mebyon, etymologically, colophon, countenance, marischal, beg, leopoldo,
# Nearest to known: used, defined, such, well, nana, called, classified, regarded,
# Average loss at step 42000: 3.439941
# Average loss at step 44000: 3.454665
# Average loss at step 46000: 3.447895
# Average loss at step 48000: 3.351796
# Average loss at step 50000: 3.385222
# Nearest to use: prefer, wie, juxtaposition, topped, explain, lagrange, tirelessly, list,
# Nearest to between: with, patriarchates, through, within, odors, in, islanders, sibling,
# Nearest to over: up, fundamental, kuru, munroe, informational, through, woodcock, rebbe,
# Nearest to s: ballantine, za, his, internationalism, raging, honourable, diomedes, grey,
# Nearest to can: may, could, would, will, must, should, cannot, might,
# Nearest to to: witches, could, would, may, will, can, towards, breatharian,
# Nearest to UNK: screwtape, ladders, miami, svenska, norse, la, j, jim,
# Nearest to united: hipc, orioles, whitfield, layoffs, childbearing, peloponnesian, across, cygnus,
# Nearest to new: second, ruinous, gladly, kauravas, manuel, laconic, barbie, connie,
# Nearest to has: had, have, was, is, having, makes, since, contains,
# Nearest to would: could, will, can, may, might, must, should, did,
# Nearest to six: eight, seven, four, nine, five, three, two, one,
# Nearest to had: has, have, was, were, having, wrc, been, bookmakers,
# Nearest to up: them, out, him, cremated, off, down, obligated, back,
# Nearest to about: mebyon, colophon, etymologically, mauss, unforgiven, dire, leopoldo, least,
# Nearest to known: used, defined, such, well, called, nana, regarded, classified,
# Average loss at step 52000: 3.434273
# Average loss at step 54000: 3.425537
# Average loss at step 56000: 3.440602
# Average loss at step 58000: 3.397581
# Average loss at step 60000: 3.395278
# Nearest to use: prefer, juxtaposition, wie, topped, exist, examination, lagrange, explain,
# Nearest to between: with, through, patriarchates, in, within, odors, exporting, sibling,
# Nearest to over: up, through, yoshinkan, consonances, into, around, disillusioned, aztec,
# Nearest to s: grey, highways, honourable, hutterite, noncommercial, records, boac, spar,
# Nearest to can: may, could, would, will, must, might, should, cannot,
# Nearest to to: towards, will, may, would, intermission, miserable, must, witches,
# Nearest to UNK: e, resource, overly, inhibiting, hardware, hematite, amal, unhindered,
# Nearest to united: hipc, orioles, whitfield, childbearing, peloponnesian, layoffs, across, saville,
# Nearest to new: laconic, kauravas, lexington, kashima, manuel, gladly, modernists, lucrative,
# Nearest to has: had, have, is, was, having, makes, includes, contains,
# Nearest to would: could, will, may, can, might, must, should, did,
# Nearest to six: eight, five, nine, four, seven, three, two, zero,
# Nearest to had: has, have, was, were, wrc, having, became, makes,
# Nearest to up: them, off, out, him, cremated, down, over, forth,
# Nearest to about: mebyon, unforgiven, on, monkey, over, ioannes, rosalynn, leopoldo,
# Nearest to known: used, defined, such, called, well, regarded, nana, instrumentals,
# Average loss at step 62000: 3.237352
# Average loss at step 64000: 3.260195
# Average loss at step 66000: 3.400389
# Average loss at step 68000: 3.396620
# Average loss at step 70000: 3.360018
# Nearest to use: prefer, wie, juxtaposition, exist, need, topped, using, explain,
# Nearest to between: with, within, patriarchates, through, odors, in, islanders, mecha,
# Nearest to over: up, about, disillusioned, aztec, cad, back, animalia, euphoric,
# Nearest to s: modernity, imperatoribus, za, wilfred, must, raging, fretless, milo,
# Nearest to can: may, could, would, will, must, should, might, cannot,
# Nearest to to: would, will, can, towards, could, breatharian, must, indignant,
# Nearest to UNK: lodges, algorithms, chanced, odin, backwards, hardliners, parsecs, airways,
# Nearest to united: hipc, orioles, peloponnesian, childbearing, layoffs, across, whitfield, sofia,
# Nearest to new: lexington, gladly, laconic, vertical, barbie, harsher, kauravas, garland,
# Nearest to has: had, have, is, was, since, having, contains, makes,
# Nearest to would: will, could, may, can, might, must, should, did,
# Nearest to six: eight, nine, seven, four, five, three, two, zero,
# Nearest to had: have, has, was, were, having, since, wrc, bookmakers,
# Nearest to up: them, off, out, cremated, him, down, back, over,
# Nearest to about: mebyon, over, ioannes, on, gylfaginning, nonsense, leopoldo, plh,
# Nearest to known: defined, used, such, called, regarded, well, nana, referred,
# Average loss at step 72000: 3.371917
# Average loss at step 74000: 3.348987
# Average loss at step 76000: 3.314701
# Average loss at step 78000: 3.350962
# Average loss at step 80000: 3.379092
# Nearest to use: prefer, wie, exist, explain, juxtaposition, need, form, list,
# Nearest to between: within, with, patriarchates, through, in, odors, among, exporting,
# Nearest to over: around, aztec, off, up, before, disillusioned, during, shores,
# Nearest to s: firstnode, whose, citigroup, eucharistic, modernity, bulletproof, fogo, raging,
# Nearest to can: could, may, will, would, must, cannot, should, might,
# Nearest to to: will, would, towards, could, witches, should, breatharian, intermission,
# Nearest to UNK: physicist, harold, morton, wilson, stirrups, techs, palomino, smith,
# Nearest to united: hipc, orioles, peloponnesian, sofia, uk, saville, childbearing, whitfield,
# Nearest to new: lexington, garland, barbie, nfc, napoleonic, reorganization, lifecycle, feb,
# Nearest to has: had, have, is, was, since, contains, having, includes,
# Nearest to would: could, will, may, might, can, should, must, cannot,
# Nearest to six: five, seven, four, eight, three, nine, two, zero,
# Nearest to had: have, has, were, was, having, wrc, never, tried,
# Nearest to up: out, off, them, him, down, cremated, forth, together,
# Nearest to about: mebyon, gylfaginning, plh, capita, over, xxx, seasons, unelected,
# Nearest to known: used, defined, regarded, such, called, referred, classified, described,
# Average loss at step 82000: 3.410920
# Average loss at step 84000: 3.410139
# Average loss at step 86000: 3.388107
# Average loss at step 88000: 3.353377
# Average loss at step 90000: 3.368054
# Nearest to use: wie, treatment, exist, prefer, juxtaposition, need, most, topped,
# Nearest to between: with, within, through, patriarchates, from, among, odors, in,
# Nearest to over: around, off, through, before, kuru, animalia, shores, during,
# Nearest to s: his, fogo, citigroup, internationalism, bezier, modernity, honourable, clones,
# Nearest to can: could, may, must, will, would, cannot, should, might,
# Nearest to to: towards, will, would, witches, stansted, could, intermission, must,
# Nearest to UNK: enrique, compton, invades, hieroglyphics, harass, rwandan, http, fluctuated,
# Nearest to united: hipc, peloponnesian, childbearing, orioles, uk, sofia, whitfield, layoffs,
# Nearest to new: gladly, garland, feb, harsher, lexington, formulae, sow, reorganization,
# Nearest to has: had, have, is, having, was, since, makes, dump,
# Nearest to would: could, will, might, may, can, must, should, did,
# Nearest to six: seven, eight, five, four, nine, three, zero, two,
# Nearest to had: has, have, was, were, having, wrc, since, began,
# Nearest to up: off, out, them, him, down, cremated, together, forth,
# Nearest to about: rosalynn, gylfaginning, epa, over, sidespin, unforgiven, netsplit, continuum,
# Nearest to known: used, defined, such, regarded, called, referred, described, well,
# Average loss at step 92000: 3.401010
# Average loss at step 94000: 3.253977
# Average loss at step 96000: 3.362956
# Average loss at step 98000: 3.242146
# Average loss at step 100000: 3.357908
# Nearest to use: wie, need, treatment, prefer, juxtaposition, using, exist, cfp,
# Nearest to between: within, with, odors, through, senses, islanders, among, patriarchates,
# Nearest to over: around, hitpa, through, before, cad, wait, exotic, oni,
# Nearest to s: whose, citigroup, his, diomedes, za, furlong, sewage, your,
# Nearest to can: could, may, will, must, would, should, cannot, might,
# Nearest to to: will, towards, must, could, can, intermission, announces, should,
# Nearest to UNK: brahmagupta, collages, tractors, parsecs, br, nss, gonzo, jpg,
# Nearest to united: peloponnesian, sofia, hipc, orioles, childbearing, netherlands, uk, whitfield,
# Nearest to new: modern, formulae, different, feb, garland, gladly, attic, dunham,
# Nearest to has: had, have, is, was, since, having, contains, icebergs,
# Nearest to would: could, will, might, may, can, must, should, did,
# Nearest to six: four, seven, nine, eight, five, three, two, zero,
# Nearest to had: has, have, was, having, were, since, would, bookmakers,
# Nearest to up: off, out, them, him, down, together, cremated, back,
# Nearest to about: approximately, rosalynn, around, colophon, epa, seasons, netsplit, least,
# Nearest to known: defined, such, used, regarded, referred, seen, listed, called,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
